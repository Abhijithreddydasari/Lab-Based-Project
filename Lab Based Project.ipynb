# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from lmfit import Model
from math import log, sqrt

# %%
data1 = pd.read_csv('plot-data_c1.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

# %%
# Gaussian function
def gaussian(x, a, b, c):
    return a*np.exp(-(x-b)**2/(2*c**2))

# Lorentzian function
def lorentzian(x, x0, gamma, A):
    return (A*gamma**2)/((x-x0)**2+gamma**2)

# %%
popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [600, 3750,150])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()

residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)
# Out:
# Cost function value for Gaussian fitting:  9993.866256732279
# FWHM for Gaussian is  159.8027085200808

# %%
popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [600, 3750,150])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()

residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Lorentzian fitting:  17552.997569979074
# FWHM for Lorentzian is  132.65954063560213

# %% [markdown]
# # Parallel momenta 2-23 nuclei

# %%
data1 = pd.read_csv('plot-data_c2.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [600, 3750,150])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [600, 3750,150])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  1547.121897322701
# FWHM for Gaussian is  149.53384300913842
# Cost function value for Lorentzian fitting:  1933.8644100914707
# FWHM for Lorentzian is  122.60404211813052

# %%
data1 = pd.read_csv('plot-data_c3.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [8000,3850,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [8000,3850,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  2064893.7013980397
# FWHM for Gaussian is  68.8019698669096
# Cost function value for Lorentzian fitting:  2857747.4674769435
# FWHM for Lorentzian is  55.67077532701312

# %%
data1 = pd.read_csv('plot-data_c4.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [1300,3850,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [1300,3850,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  51830.13103981162
# FWHM for Gaussian is  88.91644930858425
# Cost function value for Lorentzian fitting:  55594.563779364296
# FWHM for Lorentzian is  72.76110017539483

# %%
data1 = pd.read_csv('plot-data_c5.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [500,4550,200])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [500,4550,200])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  12895.312002047136
# FWHM for Gaussian is  204.42276817796096
# Cost function value for Lorentzian fitting:  11909.33388001034
# FWHM for Lorentzian is  175.8474670891264

# %%
data1 = pd.read_csv('plot-data_c6.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [70000,4650,50])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [70000,4650,50])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  266125414.73521277
# FWHM for Gaussian is  78.11215644368608
# Cost function value for Lorentzian fitting:  135278139.72100684
# FWHM for Lorentzian is  61.83957636481003

# %%
data1 = pd.read_csv('plot-data_c7.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [9500,4650,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [9500,4650,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  3262494.4809786077
# FWHM for Gaussian is  130.6672107213146
# Cost function value for Lorentzian fitting:  4457865.944091552
# FWHM for Lorentzian is  109.28787180143806

# %%
data1 = pd.read_csv('plot-data_c8.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [1400,4650,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [1400,4650,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  61402.08869929347
# FWHM for Gaussian is  142.18947457742917
# Cost function value for Lorentzian fitting:  79297.05564712317
# FWHM for Lorentzian is  117.386332465179

# %%
data1 = pd.read_csv('plot-data_c9.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [400,4650,150])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [400,4650,150])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  13082.840986559924
# FWHM for Gaussian is  176.3700325435455
# Cost function value for Lorentzian fitting:  19542.661018096536
# FWHM for Lorentzian is  149.64241374004024

# %%
data1 = pd.read_csv('plot-data_c10.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [4750,5475,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [4750,5475,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  2318034.992536052
# FWHM for Gaussian is  179.81045775569737
# Cost function value for Lorentzian fitting:  404559.37924838264
# FWHM for Lorentzian is  153.2078793578176

# %%
data1 = pd.read_csv('plot-data_c11.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [6000,5475,140])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [6000,5475,140])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  4185689.073946808
# FWHM for Gaussian is  189.010388898463
# Cost function value for Lorentzian fitting:  1121318.697873588
# FWHM for Lorentzian is  163.42306040681748

# %%
data1 = pd.read_csv('plot-data_c12.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [3600,5475,175])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [3600,5475,175])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  2262597.250653282
# FWHM for Gaussian is  211.56236224432715
# Cost function value for Lorentzian fitting:  3293731.1242237845
# FWHM for Lorentzian is  186.0971058461987

# %%
data1 = pd.read_csv('plot-data_c13.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [450,5425,175])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [450,5425,175])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  9172.158243750655
# FWHM for Gaussian is  185.4562427405137
# Cost function value for Lorentzian fitting:  25851.00614727753
# FWHM for Lorentzian is  161.65236924442735

# %%
data1 = pd.read_csv('plot-data_c14.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [60,5400,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [60,5400,125])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  39.1326701158846
# FWHM for Gaussian is  177.25274895667744
# Cost function value for Lorentzian fitting:  325.9412321143145
# FWHM for Lorentzian is  152.68202752103758

# %%
data1 = pd.read_csv('plot-data_c15.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [1000,6300,250])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [1000,6300,250])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  43763.99841043116
# FWHM for Gaussian is  222.61059025805454
# Cost function value for Lorentzian fitting:  35035.96873563069
# FWHM for Lorentzian is  189.10412923955715

# %%
data1 = pd.read_csv('plot-data_c16.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [4000,6300,275])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [4000,6300,275])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  686054.7646612761
# FWHM for Gaussian is  235.6886071759041
# Cost function value for Lorentzian fitting:  767853.1303953204
# FWHM for Lorentzian is  204.1308037571075

# %%
data1 = pd.read_csv('plot-data_c17.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [2600,6250,300])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [2600,6250,300])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  429324.160389057
# FWHM for Gaussian is  272.0421581468987
# Cost function value for Lorentzian fitting:  730404.2099840816
# FWHM for Lorentzian is  235.2724423526914

# %%
data1 = pd.read_csv('plot-data_c18.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [850,6250,250])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [850,6250,250])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  141978.67796865292
# FWHM for Gaussian is  251.92050062878553
# Cost function value for Lorentzian fitting:  208510.24494768542
# FWHM for Lorentzian is  241.8737513030821

# %%
data1 = pd.read_csv('plot-data_c19.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [65,6150,175])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1)
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  289.9221309734562
# FWHM for Gaussian is  149.89824146314726
# Cost function value for Lorentzian fitting:  316.4599322534041
# FWHM for Lorentzian is  124.37552954941509

# %%
data1 = pd.read_csv('plot-data_c20.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [420,7150,175])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [420,7150,175])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  7387.599750261814
# FWHM for Gaussian is  223.81311995983074
# Cost function value for Lorentzian fitting:  10202.361103499428
# FWHM for Lorentzian is  191.07075676733876

# %%
data1 = pd.read_csv('plot-data_c21.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [1000,7025,200])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [1000,7025,200])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  31917.79226622213
# FWHM for Gaussian is  282.83229989661885
# Cost function value for Lorentzian fitting:  123971.88164752346
# FWHM for Lorentzian is  251.61587056449275

# %%
data1 = pd.read_csv('plot-data_c22.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [1050,7000,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [1050,7000,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  40497.01718173838
# FWHM for Gaussian is  170.98109826251707
# Cost function value for Lorentzian fitting:  45201.2457994377
# FWHM for Lorentzian is  136.48972825280808

# %%
data1 = pd.read_csv('plot-data_c23.csv')
x1 = np.array(data1.iloc[:,0])
y1 = np.array(data1.iloc[:,1])

popt1, pcov1 = curve_fit(gaussian, x1, y1, p0 = [200,6950,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, gaussian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Gaussian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Gaussian Fitting for Parallel momentum')
plt.show()
residuals = y1 - gaussian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Gaussian fitting: ", ss_res)
fwhm_g = abs(2*sqrt(2*log(2))*popt1[2])
print("FWHM for Gaussian is ", fwhm_g)

popt1, pcov1 = curve_fit(lorentzian, x1, y1, p0 = [200,6950,100])
A_opt1, mu_opt1, sig_opt1 = popt1
plt.scatter(x1, y1, label='Experimental data')
x_model = np.linspace(min(x1), max(x1), 1000)
plt.plot(x_model, lorentzian(x_model, popt1[0], popt1[1], popt1[2]), 'r-', label='Lorentzian fit')
plt.legend()
plt.xlabel('Parallel momentum $P_z$ ${(MeV/c)}$')
plt.ylabel('Counts measured')
plt.title('Lorentzian Fitting for Parallel momentum')
plt.show()
residuals = y1 - lorentzian(x1, popt1[0], popt1[1], popt1[2])
ss_res = np.sum(residuals**2)
print("Cost function value for Lorentzian fitting: ", ss_res)
fwhm_l = abs(2*popt1[1])
print("FWHM for Lorentzian is ", fwhm_l)
# Out:
# Cost function value for Gaussian fitting:  2735.5582964449623
# FWHM for Gaussian is  159.70881313263456
# Cost function value for Lorentzian fitting:  716.4813257155679
# FWHM for Lorentzian is  121.72017410555806

# %%
import warnings
warnings.filterwarnings("ignore")
